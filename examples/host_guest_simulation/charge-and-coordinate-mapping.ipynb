# %%
from openeye.oechem import *
from utils import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
molecules = []

# %%
mol = process_and_convert('[O-]C(=O)c1ccccc1', 'bcd-ben/original/ben.mol2', name='ben')
molecules.append(mol)
# Out:
# Determining mapping...
# Reference → Target
# (O1   Du   )  12 →   0 (O1  )
# (C7   Du   )  11 →   1 (C1  )
# (O2   Du   )  13 →   2 (O2  )
# (C4   ca   )   6 →   3 (C2  )
# (C3   ca   )   4 →   4 (C3  )
# (C2   ca   )   2 →   5 (C4  )
# (C1   ca   )   0 →   6 (C5  )
# (C6   ca   )   9 →   7 (C6  )
# (C5   ca   )   7 →   8 (C7  )
# (H3   Du   )   5 →   9 (H1  )
# (H2   Du   )   3 →  10 (H2  )
# (H1   Du   )   1 →  11 (H3  )
# (H5   Du   )  10 →  12 (H4  )
# (H4   Du   )   8 →  13 (H5  )
# Remapping atom names...
# Reference → Target
# O1   → O1
# C7   → C1
# O2   → O2
# C4   → C2
# C3   → C3
# C2   → C4
# C1   → C5
# C6   → C6
# C5   → C7
# H3   → H1
# H2   → H2
# H1   → H3
# H5   → H4
# H4   → H5
# Remapping charges...
# Existing → New
# (O1  ) +0.000000 → -0.833675
# (C7  ) +0.000000 → +0.906879
# (O2  ) +0.000000 → -0.833677
# (C4  ) +0.000000 → -0.123507
# (C3  ) +0.000000 → -0.108918
# (C2  ) +0.000000 → -0.165876
# (C1  ) +0.000000 → -0.161879
# (C6  ) +0.000000 → -0.165876
# (C5  ) +0.000000 → -0.108918
# (H3  ) +0.000000 → +0.148111
# (H2  ) +0.000000 → +0.101076
# (H1  ) +0.000000 → +0.097073
# (H5  ) +0.000000 → +0.101076
# (H4  ) +0.000000 → +0.148111
# Found residue name = BEN
# Remapping residue names and numbers...
# Existing → New
# (O1  ) BEN     1 → BEN     1
# (C7  ) BEN     1 → BEN     1
# (O2  ) BEN     1 → BEN     1
# (C4  ) BEN     1 → BEN     1
# (C3  ) BEN     1 → BEN     1
# (C2  ) BEN     1 → BEN     1
# (C1  ) BEN     1 → BEN     1
# (C6  ) BEN     1 → BEN     1
# (C5  ) BEN     1 → BEN     1
# (H3  ) BEN     1 → BEN     1
# (H2  ) BEN     1 → BEN     1
# (H1  ) BEN     1 → BEN     1
# (H5  ) BEN     1 → BEN     1
# (H4  ) BEN     1 → BEN     1
# Remapping coordinates...
# Existing → New
# (0.0, 0.0, 0.0) → [ 20.26079941  20.88610077  37.62670135]
# (0.0, 0.0, 0.0) → [ 19.69680023  19.99410057  37.01470184]
# (0.0, 0.0, 0.0) → [ 19.13279915  19.10210037  37.62670135]
# (0.0, 0.0, 0.0) → [ 19.69680023  19.99410057  35.49769974]
# (0.0, 0.0, 0.0) → [ 19.05279922  18.97509956  34.77970123]
# (0.0, 0.0, 0.0) → [ 19.05380058  18.97610092  33.38570023]
# (0.0, 0.0, 0.0) → [ 19.69680023  19.99410057  32.68769836]
# (0.0, 0.0, 0.0) → [ 20.33979988  21.01210022  33.38570023]
# (0.0, 0.0, 0.0) → [ 20.34079933  21.01309967  34.77970123]
# (0.0, 0.0, 0.0) → [ 18.5447998   18.17110062  35.30870056]
# (0.0, 0.0, 0.0) → [ 18.54879951  18.17810059  32.84170151]
# (0.0, 0.0, 0.0) → [ 19.69680023  19.99410057  31.59770012]
# (0.0, 0.0, 0.0) → [ 20.84480095  21.81010056  32.84170151]
# (0.0, 0.0, 0.0) → [ 20.84880066  21.81710052  35.30870056]
# Either use the returned `OEMol()` or save as `mol2` to continue...

# %%
save_mol2('bcd-ben/generated/ben.oe.mol2', mol, standard=False)

# %%
from oeommtools import utils as oeommutils
omm_top, omm_pos = oeommutils.oemol_to_openmmTop(mol)

# %%
ff = ForceField('forcefield/smirnoff99Frosst.ffxml', 'forcefield/tip3p.ffxml') 
system = ff.createSystem(omm_top, 
                         [mol])

# %%
import parmed as pmd
structure = pmd.openmm.topsystem.load_topology(omm_top, system)

# %%
# Residue name is okay, but the atom type is missing.
structure.save('bcd-ben/generated/ben.pmd.mol2')
structure.save('bcd-ben/generated/ben.pmd.prmtop')

# %%
mol = process_and_convert('C([C@@H]1[C@@H]2[C@@H]([C@H]([C@H](O1)O[C@@H]3[C@H](O[C@@H]([C@@H]([C@H]3O)O)O[C@@H]4[C@H](O[C@@H]([C@@H]([C@H]4O)O)O[C@@H]5[C@H](O[C@@H]([C@@H]([C@H]5O)O)O[C@@H]6[C@H](O[C@@H]([C@@H]([C@H]6O)O)O[C@@H]7[C@H](O[C@@H]([C@@H]([C@H]7O)O)O[C@@H]8[C@H](O[C@H](O2)[C@@H]([C@H]8O)O)CO)CO)CO)CO)CO)CO)O)O)O',
                    'bcd-ben/original/bcd.mol2', name='bcd')
# Out:
# Determining mapping...
# Reference → Target
# (C6   Du   )  16 →   0 (C1  )
# (C5   Du   )  13 →   1 (C2  )
# (H5   Du   )  14 →   2 (H1  )
# (C4   Du   )  11 →   3 (C3  )
# (H4   Du   )  12 →   4 (H2  )
# (C3   Du   )   7 →   5 (C4  )
# (H3   Du   )   8 →   6 (H3  )
# (C2   Du   )   3 →   7 (C5  )
# (H2   Du   )   4 →   8 (H4  )
# (C1   Du   )   0 →   9 (C6  )
# (H1   Du   )   1 →  10 (H5  )
# (Os2  Du   )  15 →  11 (O1  )
# (Os1  Du   )   2 →  12 (O2  )
# (C10  Du   )  32 →  13 (C7  )
# (H11  Du   )  33 →  14 (H6  )
# (C11  Du   )  34 →  15 (C8  )
# (H12  Du   )  35 →  16 (H7  )
# (Os4  Du   )  36 →  17 (O3  )
# (C7   Du   )  21 →  18 (C9  )
# (H8   Du   )  22 →  19 (H8  )
# (C8   Du   )  24 →  20 (C10 )
# (H9   Du   )  25 →  21 (H9  )
# (C9   Du   )  28 →  22 (C11 )
# (H10  Du   )  29 →  23 (H10 )
# (O5   Du   )  30 →  24 (O4  )
# (O4   Du   )  26 →  25 (O5  )
# (Os3  Du   )  23 →  26 (O6  )
# (C16  Du   )  53 →  27 (C12 )
# (H18  Du   )  54 →  28 (H11 )
# (C17  Du   )  55 →  29 (C13 )
# (H19  Du   )  56 →  30 (H12 )
# (Os6  Du   )  57 →  31 (O7  )
# (C13  Du   )  42 →  32 (C14 )
# (H15  Du   )  43 →  33 (H13 )
# (C14  Du   )  45 →  34 (C15 )
# (H16  Du   )  46 →  35 (H14 )
# (C15  Du   )  49 →  36 (C16 )
# (H17  Du   )  50 →  37 (H15 )
# (O8   Du   )  51 →  38 (O8  )
# (O7   Du   )  47 →  39 (O9  )
# (Os5  Du   )  44 →  40 (O10 )
# (C22  Du   )  74 →  41 (C17 )
# (H25  Du   )  75 →  42 (H16 )
# (C23  Du   )  76 →  43 (C18 )
# (H26  Du   )  77 →  44 (H17 )
# (Os8  Du   )  78 →  45 (O11 )
# (C19  Du   )  63 →  46 (C19 )
# (H22  Du   )  64 →  47 (H18 )
# (C20  Du   )  66 →  48 (C20 )
# (H23  Du   )  67 →  49 (H19 )
# (C21  Du   )  70 →  50 (C21 )
# (H24  Du   )  71 →  51 (H20 )
# (O11  Du   )  72 →  52 (O12 )
# (O10  Du   )  68 →  53 (O13 )
# (Os7  Du   )  65 →  54 (O14 )
# (C28  Du   )  95 →  55 (C22 )
# (H32  Du   )  96 →  56 (H21 )
# (C29  Du   )  97 →  57 (C23 )
# (H33  Du   )  98 →  58 (H22 )
# (Os10 Du   )  99 →  59 (O15 )
# (C25  Du   )  84 →  60 (C24 )
# (H29  Du   )  85 →  61 (H23 )
# (C26  Du   )  87 →  62 (C25 )
# (H30  Du   )  88 →  63 (H24 )
# (C27  Du   )  91 →  64 (C26 )
# (H31  Du   )  92 →  65 (H25 )
# (O14  Du   )  93 →  66 (O16 )
# (O13  Du   )  89 →  67 (O17 )
# (Os9  Du   )  86 →  68 (O18 )
# (C34  Du   ) 116 →  69 (C27 )
# (H39  Du   ) 117 →  70 (H26 )
# (C35  Du   ) 118 →  71 (C28 )
# (H40  Du   ) 119 →  72 (H27 )
# (Os12 Du   ) 120 →  73 (O19 )
# (C31  Du   ) 105 →  74 (C29 )
# (H36  Du   ) 106 →  75 (H28 )
# (C32  Du   ) 108 →  76 (C30 )
# (H37  Du   ) 109 →  77 (H29 )
# (C33  Du   ) 112 →  78 (C31 )
# (H38  Du   ) 113 →  79 (H30 )
# (O17  Du   ) 114 →  80 (O20 )
# (O16  Du   ) 110 →  81 (O21 )
# (Os11 Du   ) 107 →  82 (O22 )
# (C40  Du   ) 137 →  83 (C32 )
# (H46  Du   ) 138 →  84 (H31 )
# (C41  Du   ) 139 →  85 (C33 )
# (H47  Du   ) 140 →  86 (H32 )
# (Os14 Du   ) 141 →  87 (O23 )
# (C37  Du   ) 126 →  88 (C34 )
# (H43  Du   ) 127 →  89 (H33 )
# (Os13 Du   ) 128 →  90 (O24 )
# (C38  Du   ) 129 →  91 (C35 )
# (H44  Du   ) 130 →  92 (H34 )
# (C39  Du   ) 133 →  93 (C36 )
# (H45  Du   ) 134 →  94 (H35 )
# (O20  Du   ) 135 →  95 (O25 )
# (O19  Du   ) 131 →  96 (O26 )
# (C42  Du   ) 142 →  97 (C37 )
# (O21  Du   ) 145 →  98 (O27 )
# (C36  Du   ) 121 →  99 (C38 )
# (O18  Du   ) 124 → 100 (O28 )
# (C30  Du   ) 100 → 101 (C39 )
# (O15  Du   ) 103 → 102 (O29 )
# (C24  Du   )  79 → 103 (C40 )
# (O12  Du   )  82 → 104 (O30 )
# (C18  Du   )  58 → 105 (C41 )
# (O9   Du   )  61 → 106 (O31 )
# (C12  Du   )  37 → 107 (C42 )
# (O6   Du   )  40 → 108 (O32 )
# (O1   Du   )   5 → 109 (O33 )
# (O2   Du   )   9 → 110 (O34 )
# (O3   Du   )  19 → 111 (O35 )
# (H6   Du   )  17 → 112 (H36 )
# (H7   Du   )  18 → 113 (H37 )
# (Ho5  Du   )  31 → 114 (H38 )
# (Ho4  Du   )  27 → 115 (H39 )
# (Ho8  Du   )  52 → 116 (H40 )
# (Ho7  Du   )  48 → 117 (H41 )
# (Ho11 Du   )  73 → 118 (H42 )
# (Ho10 Du   )  69 → 119 (H43 )
# (Ho14 Du   )  94 → 120 (H44 )
# (Ho13 Du   )  90 → 121 (H45 )
# (Ho17 Du   ) 115 → 122 (H46 )
# (Ho16 Du   ) 111 → 123 (H47 )
# (Ho20 Du   ) 136 → 124 (H48 )
# (Ho19 Du   ) 132 → 125 (H49 )
# (H48  Du   ) 143 → 126 (H50 )
# (H49  Du   ) 144 → 127 (H51 )
# (Ho21 Du   ) 146 → 128 (H52 )
# (H41  Du   ) 122 → 129 (H53 )
# (H42  Du   ) 123 → 130 (H54 )
# (Ho18 Du   ) 125 → 131 (H55 )
# (H34  Du   ) 101 → 132 (H56 )
# (H35  Du   ) 102 → 133 (H57 )
# (Ho15 Du   ) 104 → 134 (H58 )
# (H27  Du   )  80 → 135 (H59 )
# (H28  Du   )  81 → 136 (H60 )
# (Ho12 Du   )  83 → 137 (H61 )
# (H20  Du   )  59 → 138 (H62 )
# (H21  Du   )  60 → 139 (H63 )
# (Ho9  Du   )  62 → 140 (H64 )
# (H13  Du   )  38 → 141 (H65 )
# (H14  Du   )  39 → 142 (H66 )
# (Ho6  Du   )  41 → 143 (H67 )
# (Ho1  Du   )   6 → 144 (H68 )
# (Ho2  Du   )  10 → 145 (H69 )
# (Ho3  Du   )  20 → 146 (H70 )
# Remapping atom names...
# Reference → Target
# C6   → C1
# C5   → C2
# H5   → H1
# C4   → C3
# H4   → H2
# C3   → C4
# H3   → H3
# C2   → C5
# H2   → H4
# C1   → C6
# H1   → H5
# Os2  → O1
# Os1  → O2
# C10  → C7
# H11  → H6
# C11  → C8
# H12  → H7
# Os4  → O3
# C7   → C9
# H8   → H8
# C8   → C10
# H9   → H9
# C9   → C11
# H10  → H10
# O5   → O4
# O4   → O5
# Os3  → O6
# C16  → C12
# H18  → H11
# C17  → C13
# H19  → H12
# Os6  → O7
# C13  → C14
# H15  → H13
# C14  → C15
# H16  → H14
# C15  → C16
# H17  → H15
# O8   → O8
# O7   → O9
# Os5  → O10
# C22  → C17
# H25  → H16
# C23  → C18
# H26  → H17
# Os8  → O11
# C19  → C19
# H22  → H18
# C20  → C20
# H23  → H19
# C21  → C21
# H24  → H20
# O11  → O12
# O10  → O13
# Os7  → O14
# C28  → C22
# H32  → H21
# C29  → C23
# H33  → H22
# Os10 → O15
# C25  → C24
# H29  → H23
# C26  → C25
# H30  → H24
# C27  → C26
# H31  → H25
# O14  → O16
# O13  → O17
# Os9  → O18
# C34  → C27
# H39  → H26
# C35  → C28
# H40  → H27
# Os12 → O19
# C31  → C29
# H36  → H28
# C32  → C30
# H37  → H29
# C33  → C31
# H38  → H30
# O17  → O20
# O16  → O21
# Os11 → O22
# C40  → C32
# H46  → H31
# C41  → C33
# H47  → H32
# Os14 → O23
# C37  → C34
# H43  → H33
# Os13 → O24
# C38  → C35
# H44  → H34
# C39  → C36
# H45  → H35
# O20  → O25
# O19  → O26
# C42  → C37
# O21  → O27
# C36  → C38
# O18  → O28
# C30  → C39
# O15  → O29
# C24  → C40
# O12  → O30
# C18  → C41
# O9   → O31
# C12  → C42
# O6   → O32
# O1   → O33
# O2   → O34
# O3   → O35
# H6   → H36
# H7   → H37
# Ho5  → H38
# Ho4  → H39
# Ho8  → H40
# Ho7  → H41
# Ho11 → H42
# Ho10 → H43
# Ho14 → H44
# Ho13 → H45
# Ho17 → H46
# Ho16 → H47
# Ho20 → H48
# Ho19 → H49
# H48  → H50
# H49  → H51
# Ho21 → H52
# H41  → H53
# H42  → H54
# Ho18 → H55
# H34  → H56
# H35  → H57
# Ho15 → H58
# H27  → H59
# H28  → H60
# Ho12 → H61
# H20  → H62
# H21  → H63
# Ho9  → H64
# H13  → H65
# H14  → H66
# Ho6  → H67
# Ho1  → H68
# Ho2  → H69
# Ho3  → H70
# Remapping charges...
# Existing → New
# (C6  ) +0.000000 → +0.141081
# (C5  ) +0.000000 → +0.104343
# (H5  ) +0.000000 → +0.068516
# (C4  ) +0.000000 → +0.127621
# (H4  ) +0.000000 → +0.080661
# (C3  ) +0.000000 → +0.093211
# (H3  ) +0.000000 → +0.064468
# (C2  ) +0.000000 → +0.092199
# (H2  ) +0.000000 → +0.102926
# (C1  ) +0.000000 → +0.304529
# (H1  ) +0.000000 → +0.090782
# (Os2 ) +0.000000 → -0.427383
# (Os1 ) +0.000000 → -0.453070
# (C10 ) +0.000000 → +0.127621
# (H11 ) +0.000000 → +0.080661
# (C11 ) +0.000000 → +0.104343
# (H12 ) +0.000000 → +0.068516
# (Os4 ) +0.000000 → -0.427383
# (C7  ) +0.000000 → +0.304529
# (H8  ) +0.000000 → +0.090782
# (C8  ) +0.000000 → +0.092199
# (H9  ) +0.000000 → +0.102926
# (C9  ) +0.000000 → +0.093211
# (H10 ) +0.000000 → +0.064468
# (O5  ) +0.000000 → -0.592567
# (O4  ) +0.000000 → -0.586639
# (Os3 ) +0.000000 → -0.453070
# (C16 ) +0.000000 → +0.127621
# (H18 ) +0.000000 → +0.080661
# (C17 ) +0.000000 → +0.104343
# (H19 ) +0.000000 → +0.068516
# (Os6 ) +0.000000 → -0.427383
# (C13 ) +0.000000 → +0.304529
# (H15 ) +0.000000 → +0.090782
# (C14 ) +0.000000 → +0.092199
# (H16 ) +0.000000 → +0.102926
# (C15 ) +0.000000 → +0.093211
# (H17 ) +0.000000 → +0.064468
# (O8  ) +0.000000 → -0.592567
# (O7  ) +0.000000 → -0.586639
# (Os5 ) +0.000000 → -0.453070
# (C22 ) +0.000000 → +0.127621
# (H25 ) +0.000000 → +0.080661
# (C23 ) +0.000000 → +0.104343
# (H26 ) +0.000000 → +0.068516
# (Os8 ) +0.000000 → -0.427383
# (C19 ) +0.000000 → +0.304529
# (H22 ) +0.000000 → +0.090782
# (C20 ) +0.000000 → +0.092199
# (H23 ) +0.000000 → +0.102926
# (C21 ) +0.000000 → +0.093211
# (H24 ) +0.000000 → +0.064468
# (O11 ) +0.000000 → -0.592567
# (O10 ) +0.000000 → -0.586639
# (Os7 ) +0.000000 → -0.453070
# (C28 ) +0.000000 → +0.127621
# (H32 ) +0.000000 → +0.080661
# (C29 ) +0.000000 → +0.104343
# (H33 ) +0.000000 → +0.068516
# (Os10) +0.000000 → -0.427383
# (C25 ) +0.000000 → +0.304529
# (H29 ) +0.000000 → +0.090782
# (C26 ) +0.000000 → +0.092199
# (H30 ) +0.000000 → +0.102926
# (C27 ) +0.000000 → +0.093211
# (H31 ) +0.000000 → +0.064468
# (O14 ) +0.000000 → -0.592567
# (O13 ) +0.000000 → -0.586639
# (Os9 ) +0.000000 → -0.453070
# (C34 ) +0.000000 → +0.127621
# (H39 ) +0.000000 → +0.080661
# (C35 ) +0.000000 → +0.104343
# (H40 ) +0.000000 → +0.068516
# (Os12) +0.000000 → -0.427383
# (C31 ) +0.000000 → +0.304529
# (H36 ) +0.000000 → +0.090782
# (C32 ) +0.000000 → +0.092199
# (H37 ) +0.000000 → +0.102926
# (C33 ) +0.000000 → +0.093211
# (H38 ) +0.000000 → +0.064468
# (O17 ) +0.000000 → -0.592567
# (O16 ) +0.000000 → -0.586639
# (Os11) +0.000000 → -0.453070
# (C40 ) +0.000000 → +0.127621
# (H46 ) +0.000000 → +0.080661
# (C41 ) +0.000000 → +0.104343
# (H47 ) +0.000000 → +0.068516
# (Os14) +0.000000 → -0.427383
# (C37 ) +0.000000 → +0.304529
# (H43 ) +0.000000 → +0.090782
# (Os13) +0.000000 → -0.453070
# (C38 ) +0.000000 → +0.092199
# (H44 ) +0.000000 → +0.102926
# (C39 ) +0.000000 → +0.093211
# (H45 ) +0.000000 → +0.064468
# (O20 ) +0.000000 → -0.592567
# (O19 ) +0.000000 → -0.586639
# (C42 ) +0.000000 → +0.141081
# (O21 ) +0.000000 → -0.593555
# (C36 ) +0.000000 → +0.141081
# (O18 ) +0.000000 → -0.593555
# (C30 ) +0.000000 → +0.141081
# (O15 ) +0.000000 → -0.593555
# (C24 ) +0.000000 → +0.141081
# (O12 ) +0.000000 → -0.593555
# (C18 ) +0.000000 → +0.141081
# (O9  ) +0.000000 → -0.593555
# (C12 ) +0.000000 → +0.141081
# (O6  ) +0.000000 → -0.593555
# (O1  ) +0.000000 → -0.586639
# (O2  ) +0.000000 → -0.592567
# (O3  ) +0.000000 → -0.593555
# (H6  ) +0.000000 → +0.057384
# (H7  ) +0.000000 → +0.057384
# (Ho5 ) +0.000000 → +0.421017
# (Ho4 ) +0.000000 → +0.425065
# (Ho8 ) +0.000000 → +0.421017
# (Ho7 ) +0.000000 → +0.425065
# (Ho11) +0.000000 → +0.421017
# (Ho10) +0.000000 → +0.425065
# (Ho14) +0.000000 → +0.421017
# (Ho13) +0.000000 → +0.425065
# (Ho17) +0.000000 → +0.421017
# (Ho16) +0.000000 → +0.425065
# (Ho20) +0.000000 → +0.421017
# (Ho19) +0.000000 → +0.425065
# (H48 ) +0.000000 → +0.057384
# (H49 ) +0.000000 → +0.057384
# (Ho21) +0.000000 → +0.422027
# (H41 ) +0.000000 → +0.057384
# (H42 ) +0.000000 → +0.057384
# (Ho18) +0.000000 → +0.422027
# (H34 ) +0.000000 → +0.057384
# (H35 ) +0.000000 → +0.057384
# (Ho15) +0.000000 → +0.422027
# (H27 ) +0.000000 → +0.057384
# (H28 ) +0.000000 → +0.057384
# (Ho12) +0.000000 → +0.422027
# (H20 ) +0.000000 → +0.057384
# (H21 ) +0.000000 → +0.057384
# (Ho9 ) +0.000000 → +0.422027
# (H13 ) +0.000000 → +0.057384
# (H14 ) +0.000000 → +0.057384
# (Ho6 ) +0.000000 → +0.422027
# (Ho1 ) +0.000000 → +0.425065
# (Ho2 ) +0.000000 → +0.421017
# (Ho3 ) +0.000000 → +0.422027
# Found residue name = MGO
# Remapping residue names and numbers...
# Existing → New
# (C6  ) MGO     1 → MGO     1
# (C5  ) MGO     1 → MGO     1
# (H5  ) MGO     1 → MGO     1
# (C4  ) MGO     1 → MGO     1
# (H4  ) MGO     1 → MGO     1
# (C3  ) MGO     1 → MGO     1
# (H3  ) MGO     1 → MGO     1
# (C2  ) MGO     1 → MGO     1
# (H2  ) MGO     1 → MGO     1
# (C1  ) MGO     1 → MGO     1
# (H1  ) MGO     1 → MGO     1
# (Os2 ) MGO     1 → MGO     1
# (Os1 ) MGO     1 → MGO     1
# (C10 ) MGO     1 → MGO     1
# (H11 ) MGO     1 → MGO     1
# (C11 ) MGO     1 → MGO     1
# (H12 ) MGO     1 → MGO     1
# (Os4 ) MGO     1 → MGO     1
# (C7  ) MGO     1 → MGO     1
# (H8  ) MGO     1 → MGO     1
# (C8  ) MGO     1 → MGO     1
# (H9  ) MGO     1 → MGO     1
# (C9  ) MGO     1 → MGO     1
# (H10 ) MGO     1 → MGO     1
# (O5  ) MGO     1 → MGO     1
# (O4  ) MGO     1 → MGO     1
# (Os3 ) MGO     1 → MGO     1
# (C16 ) MGO     1 → MGO     1
# (H18 ) MGO     1 → MGO     1
# (C17 ) MGO     1 → MGO     1
# (H19 ) MGO     1 → MGO     1
# (Os6 ) MGO     1 → MGO     1
# (C13 ) MGO     1 → MGO     1
# (H15 ) MGO     1 → MGO     1
# (C14 ) MGO     1 → MGO     1
# (H16 ) MGO     1 → MGO     1
# (C15 ) MGO     1 → MGO     1
# (H17 ) MGO     1 → MGO     1
# (O8  ) MGO     1 → MGO     1
# (O7  ) MGO     1 → MGO     1
# (Os5 ) MGO     1 → MGO     1
# (C22 ) MGO     1 → MGO     1
# (H25 ) MGO     1 → MGO     1
# (C23 ) MGO     1 → MGO     1
# (H26 ) MGO     1 → MGO     1
# (Os8 ) MGO     1 → MGO     1
# (C19 ) MGO     1 → MGO     1
# (H22 ) MGO     1 → MGO     1
# (C20 ) MGO     1 → MGO     1
# (H23 ) MGO     1 → MGO     1
# (C21 ) MGO     1 → MGO     1
# (H24 ) MGO     1 → MGO     1
# (O11 ) MGO     1 → MGO     1
# (O10 ) MGO     1 → MGO     1
# (Os7 ) MGO     1 → MGO     1
# (C28 ) MGO     1 → MGO     1
# (H32 ) MGO     1 → MGO     1
# (C29 ) MGO     1 → MGO     1
# (H33 ) MGO     1 → MGO     1
# (Os10) MGO     1 → MGO     1
# (C25 ) MGO     1 → MGO     1
# (H29 ) MGO     1 → MGO     1
# (C26 ) MGO     1 → MGO     1
# (H30 ) MGO     1 → MGO     1
# (C27 ) MGO     1 → MGO     1
# (H31 ) MGO     1 → MGO     1
# (O14 ) MGO     1 → MGO     1
# (O13 ) MGO     1 → MGO     1
# (Os9 ) MGO     1 → MGO     1
# (C34 ) MGO     1 → MGO     1
# (H39 ) MGO     1 → MGO     1
# (C35 ) MGO     1 → MGO     1
# (H40 ) MGO     1 → MGO     1
# (Os12) MGO     1 → MGO     1
# (C31 ) MGO     1 → MGO     1
# (H36 ) MGO     1 → MGO     1
# (C32 ) MGO     1 → MGO     1
# (H37 ) MGO     1 → MGO     1
# (C33 ) MGO     1 → MGO     1
# (H38 ) MGO     1 → MGO     1
# (O17 ) MGO     1 → MGO     1
# (O16 ) MGO     1 → MGO     1
# (Os11) MGO     1 → MGO     1
# (C40 ) MGO     1 → MGO     1
# (H46 ) MGO     1 → MGO     1
# (C41 ) MGO     1 → MGO     1
# (H47 ) MGO     1 → MGO     1
# (Os14) MGO     1 → MGO     1
# (C37 ) MGO     1 → MGO     1
# (H43 ) MGO     1 → MGO     1
# (Os13) MGO     1 → MGO     1
# (C38 ) MGO     1 → MGO     1
# (H44 ) MGO     1 → MGO     1
# (C39 ) MGO     1 → MGO     1
# (H45 ) MGO     1 → MGO     1
# (O20 ) MGO     1 → MGO     1
# (O19 ) MGO     1 → MGO     1
# (C42 ) MGO     1 → MGO     1
# (O21 ) MGO     1 → MGO     1
# (C36 ) MGO     1 → MGO     1
# (O18 ) MGO     1 → MGO     1
# (C30 ) MGO     1 → MGO     1
# (O15 ) MGO     1 → MGO     1
# (C24 ) MGO     1 → MGO     1
# (O12 ) MGO     1 → MGO     1
# (C18 ) MGO     1 → MGO     1
# (O9  ) MGO     1 → MGO     1
# (C12 ) MGO     1 → MGO     1
# (O6  ) MGO     1 → MGO     1
# (O1  ) MGO     1 → MGO     1
# (O2  ) MGO     1 → MGO     1
# (O3  ) MGO     1 → MGO     1
# (H6  ) MGO     1 → MGO     1
# (H7  ) MGO     1 → MGO     1
# (Ho5 ) MGO     1 → MGO     1
# (Ho4 ) MGO     1 → MGO     1
# (Ho8 ) MGO     1 → MGO     1
# (Ho7 ) MGO     1 → MGO     1
# (Ho11) MGO     1 → MGO     1
# (Ho10) MGO     1 → MGO     1
# (Ho14) MGO     1 → MGO     1
# (Ho13) MGO     1 → MGO     1
# (Ho17) MGO     1 → MGO     1
# (Ho16) MGO     1 → MGO     1
# (Ho20) MGO     1 → MGO     1
# (Ho19) MGO     1 → MGO     1
# (H48 ) MGO     1 → MGO     1
# (H49 ) MGO     1 → MGO     1
# (Ho21) MGO     1 → MGO     1
# (H41 ) MGO     1 → MGO     1
# (H42 ) MGO     1 → MGO     1
# (Ho18) MGO     1 → MGO     1
# (H34 ) MGO     1 → MGO     1
# (H35 ) MGO     1 → MGO     1
# (Ho15) MGO     1 → MGO     1
# (H27 ) MGO     1 → MGO     1
# (H28 ) MGO     1 → MGO     1
# (Ho12) MGO     1 → MGO     1
# (H20 ) MGO     1 → MGO     1
# (H21 ) MGO     1 → MGO     1
# (Ho9 ) MGO     1 → MGO     1
# (H13 ) MGO     1 → MGO     1
# (H14 ) MGO     1 → MGO     1
# (Ho6 ) MGO     1 → MGO     1
# (Ho1 ) MGO     1 → MGO     1
# (Ho2 ) MGO     1 → MGO     1
# (Ho3 ) MGO     1 → MGO     1
# Remapping coordinates...
# Existing → New
# (0.0, 0.0, 0.0) → [ 19.50079918  14.93610001  31.46069908]
# (0.0, 0.0, 0.0) → [ 18.81279945  15.02009964  32.83069992]
# (0.0, 0.0, 0.0) → [ 18.70779991  16.08510017  33.05270004]
# (0.0, 0.0, 0.0) → [ 19.5428009   14.36310005  34.01169968]
# (0.0, 0.0, 0.0) → [ 19.70079994  13.30210018  33.79970169]
# (0.0, 0.0, 0.0) → [ 18.74379921  14.49709988  35.29869843]
# (0.0, 0.0, 0.0) → [ 18.67779922  15.54909992  35.59370041]
# (0.0, 0.0, 0.0) → [ 17.34980011  13.93610001  35.10969925]
# (0.0, 0.0, 0.0) → [ 17.4008007   12.85910034  34.92470169]
# (0.0, 0.0, 0.0) → [ 16.64279938  14.62310028  33.94469833]
# (0.0, 0.0, 0.0) → [ 15.65079975  14.1480999   33.81570053]
# (0.0, 0.0, 0.0) → [ 17.44879913  14.43910027  32.72269821]
# (0.0, 0.0, 0.0) → [ 16.51679993  16.05509949  34.24769974]
# (0.0, 0.0, 0.0) → [ 15.17280006  16.59009933  34.01269913]
# (0.0, 0.0, 0.0) → [ 14.44180012  15.80609989  33.79970169]
# (0.0, 0.0, 0.0) → [ 15.23079967  17.57110023  32.83069992]
# (0.0, 0.0, 0.0) → [ 15.99779987  18.31609917  33.05369949]
# (0.0, 0.0, 0.0) → [ 13.92580032  18.27610016  32.72269821]
# (0.0, 0.0, 0.0) → [ 13.56779957  19.02009964  33.9457016 ]
# (0.0, 0.0, 0.0) → [ 12.57680035  19.49909973  33.81769943]
# (0.0, 0.0, 0.0) → [ 13.4708004   18.03809929  35.1106987 ]
# (0.0, 0.0, 0.0) → [ 12.66079998  17.32710075  34.92570114]
# (0.0, 0.0, 0.0) → [ 14.78079987  17.29910088  35.29769897]
# (0.0, 0.0, 0.0) → [ 15.5618      18.00510025  35.59370041]
# (0.0, 0.0, 0.0) → [ 14.55679989  16.3260994   36.33069992]
# (0.0, 0.0, 0.0) → [ 13.21580029  18.75510025  36.32870102]
# (0.0, 0.0, 0.0) → [ 14.60879993  20.01110077  34.24869919]
# (0.0, 0.0, 0.0) → [ 14.18879986  21.39609909  34.01269913]
# (0.0, 0.0, 0.0) → [ 13.11979961  21.47909927  33.80170059]
# (0.0, 0.0, 0.0) → [ 14.99180031  21.96209908  32.83169937]
# (0.0, 0.0, 0.0) → [ 16.05279922  21.82710075  33.05369949]
# (0.0, 0.0, 0.0) → [ 14.72879982  23.42210007  32.72370148]
# (0.0, 0.0, 0.0) → [ 15.08780003  24.16609955  33.94670105]
# (0.0, 0.0, 0.0) → [ 14.8458004   25.2390995   33.81769943]
# (0.0, 0.0, 0.0) → [ 14.26179981  23.6291008   35.1106987 ]
# (0.0, 0.0, 0.0) → [ 13.19979954  23.81809998  34.92670059]
# (0.0, 0.0, 0.0) → [ 14.49979973  22.14410019  35.29869843]
# (0.0, 0.0, 0.0) → [ 15.53880024  21.97410011  35.59370041]
# (0.0, 0.0, 0.0) → [ 13.59980011  21.71209908  36.33169937]
# (0.0, 0.0, 0.0) → [ 14.66279984  24.27610016  36.32970047]
# (0.0, 0.0, 0.0) → [ 16.51180077  23.96910095  34.24869919]
# (0.0, 0.0, 0.0) → [ 17.33279991  25.16010094  34.01269913]
# (0.0, 0.0, 0.0) → [ 16.73180008  26.04809952  33.80070114]
# (0.0, 0.0, 0.0) → [ 18.2758007   24.88509941  32.83169937]
# (0.0, 0.0, 0.0) → [ 18.83180046  23.9720993   33.05369949]
# (0.0, 0.0, 0.0) → [ 19.25379944  26.00110054  32.72269821]
# (0.0, 0.0, 0.0) → [ 20.05979919  26.18510056  33.94469833]
# (0.0, 0.0, 0.0) → [ 20.74679947  27.04409981  33.81669998]
# (0.0, 0.0, 0.0) → [ 19.12380028  26.49710083  35.10969925]
# (0.0, 0.0, 0.0) → [ 18.61079979  27.44510078  34.92470169]
# (0.0, 0.0, 0.0) → [ 18.1128006   25.38610077  35.29769897]
# (0.0, 0.0, 0.0) → [ 18.62680054  24.46710014  35.59370041]
# (0.0, 0.0, 0.0) → [ 17.21279907  25.82010078  36.33069992]
# (0.0, 0.0, 0.0) → [ 19.88080025  26.58709908  36.32870102]
# (0.0, 0.0, 0.0) → [ 20.7928009   24.94910049  34.24769974]
# (0.0, 0.0, 0.0) → [ 22.23679924  25.05109978  34.01169968]
# (0.0, 0.0, 0.0) → [ 22.55579948  26.07410049  33.79869843]
# (0.0, 0.0, 0.0) → [ 22.60880089  24.14109993  32.83069992]
# (0.0, 0.0, 0.0) → [ 22.24279976  23.13710022  33.05369949]
# (0.0, 0.0, 0.0) → [ 24.09180069  24.07309914  32.72169876]
# (0.0, 0.0, 0.0) → [ 24.7378006   23.55809975  33.94469833]
# (0.0, 0.0, 0.0) → [ 25.83779907  23.55610085  33.81470108]
# (0.0, 0.0, 0.0) → [ 24.3987999   24.48410034  35.1086998 ]
# (0.0, 0.0, 0.0) → [ 24.81979942  25.47610092  34.92369843]
# (0.0, 0.0, 0.0) → [ 22.8987999   24.58209991  35.29769897]
# (0.0, 0.0, 0.0) → [ 22.50079918  23.60709953  35.59270096]
# (0.0, 0.0, 0.0) → [ 22.67679977  25.55610085  36.33069992]
# (0.0, 0.0, 0.0) → [ 24.93980026  23.94910049  36.32770157]
# (0.0, 0.0, 0.0) → [ 24.22879982  22.21409988  34.24769974]
# (0.0, 0.0, 0.0) → [ 25.20879936  21.14710045  34.01169968]
# (0.0, 0.0, 0.0) → [ 26.20680046  21.53709984  33.79970169]
# (0.0, 0.0, 0.0) → [ 24.72979927  20.28910065  32.83169937]
# (0.0, 0.0, 0.0) → [ 23.71680069  19.95009995  33.05270004]
# (0.0, 0.0, 0.0) → [ 25.60079956  19.08709908  32.72269821]
# (0.0, 0.0, 0.0) → [ 25.59980011  18.26210022  33.9457016 ]
# (0.0, 0.0, 0.0) → [ 26.28479958  17.40010071  33.81769943]
# (0.0, 0.0, 0.0) → [ 26.1128006   19.10510063  35.1106987 ]
# (0.0, 0.0, 0.0) → [ 27.1508007   19.39410019  34.92570114]
# (0.0, 0.0, 0.0) → [ 25.25379944  20.33810043  35.29869843]
# (0.0, 0.0, 0.0) → [ 24.24379921  20.0401001   35.59370041]
# (0.0, 0.0, 0.0) → [ 25.87680054  21.11910057  36.33169937]
# (0.0, 0.0, 0.0) → [ 26.03179932  18.34810066  36.32870102]
# (0.0, 0.0, 0.0) → [ 24.23180008  17.82110023  34.24869919]
# (0.0, 0.0, 0.0) → [ 24.00979996  16.39109993  34.01269913]
# (0.0, 0.0, 0.0) → [ 24.9368      15.85309982  33.80070114]
# (0.0, 0.0, 0.0) → [ 23.03980064  16.23010063  32.83069992]
# (0.0, 0.0, 0.0) → [ 22.14279938  16.81209946  33.05369949]
# (0.0, 0.0, 0.0) → [ 22.64380074  14.80109978  32.72370148]
# (0.0, 0.0, 0.0) → [ 21.99679947  14.28509998  33.9457016 ]
# (0.0, 0.0, 0.0) → [ 21.74979973  13.21310043  33.81769943]
# (0.0, 0.0, 0.0) → [ 20.80080032  15.08110046  34.24869919]
# (0.0, 0.0, 0.0) → [ 22.97579956  14.41009998  35.1106987 ]
# (0.0, 0.0, 0.0) → [ 23.84880066  13.77910042  34.92570114]
# (0.0, 0.0, 0.0) → [ 23.40480042  15.85009956  35.29869843]
# (0.0, 0.0, 0.0) → [ 22.5428009   16.45509911  35.59370041]
# (0.0, 0.0, 0.0) → [ 24.40279961  15.85009956  36.33269882]
# (0.0, 0.0, 0.0) → [ 22.33279991  14.00209999  36.32870102]
# (0.0, 0.0, 0.0) → [ 23.53479958  16.71509933  31.46069908]
# (0.0, 0.0, 0.0) → [ 24.95879936  16.5760994   31.35569954]
# (0.0, 0.0, 0.0) → [ 24.65979958  20.97809982  31.46069908]
# (0.0, 0.0, 0.0) → [ 25.65480042  22.0041008   31.35470009]
# (0.0, 0.0, 0.0) → [ 22.0258007   24.51510048  31.45969963]
# (0.0, 0.0, 0.0) → [ 21.84480095  25.93309975  31.35370064]
# (0.0, 0.0, 0.0) → [ 17.61980057  24.66309929  31.46069908]
# (0.0, 0.0, 0.0) → [ 16.39780045  25.40410042  31.35569954]
# (0.0, 0.0, 0.0) → [ 14.7567997   21.31010056  31.46170044]
# (0.0, 0.0, 0.0) → [ 13.41380024  20.81710052  31.35569954]
# (0.0, 0.0, 0.0) → [ 15.59379959  16.98110008  31.46069908]
# (0.0, 0.0, 0.0) → [ 15.14179993  15.62510014  31.35470009]
# (0.0, 0.0, 0.0) → [ 16.62879944  14.1821003   36.32870102]
# (0.0, 0.0, 0.0) → [ 19.36580086  13.71609974  36.33169937]
# (0.0, 0.0, 0.0) → [ 20.27980042  13.73810005  31.35470009]
# (0.0, 0.0, 0.0) → [ 20.16279984  15.79510021  31.32869911]
# (0.0, 0.0, 0.0) → [ 18.75379944  14.95909977  30.6637001 ]
# (0.0, 0.0, 0.0) → [ 13.97879982  16.74810028  36.98270035]
# (0.0, 0.0, 0.0) → [ 13.43080044  19.69510078  36.21369934]
# (0.0, 0.0, 0.0) → [ 13.56980038  22.42810059  36.9836998 ]
# (0.0, 0.0, 0.0) → [ 15.53079987  24.69409943  36.21369934]
# (0.0, 0.0, 0.0) → [ 17.75379944  26.28910065  36.9817009 ]
# (0.0, 0.0, 0.0) → [ 20.74979973  26.16909981  36.21269989]
# (0.0, 0.0, 0.0) → [ 23.38080025  25.42609978  36.9817009 ]
# (0.0, 0.0, 0.0) → [ 25.15480042  23.00909996  36.21269989]
# (0.0, 0.0, 0.0) → [ 26.21479988  20.4871006   36.98270035]
# (0.0, 0.0, 0.0) → [ 25.43079948  17.59410095  36.21369934]
# (0.0, 0.0, 0.0) → [ 24.11980057  15.19309998  36.98270035]
# (0.0, 0.0, 0.0) → [ 21.36879921  14.00109959  36.21369934]
# (0.0, 0.0, 0.0) → [ 23.27680016  17.76810074  31.32769966]
# (0.0, 0.0, 0.0) → [ 23.05179977  16.14509964  30.6637001 ]
# (0.0, 0.0, 0.0) → [ 25.3647995   17.39109993  31.67770004]
# (0.0, 0.0, 0.0) → [ 23.67580032  21.4321003   31.32869911]
# (0.0, 0.0, 0.0) → [ 24.80380058  20.24410057  30.6637001 ]
# (0.0, 0.0, 0.0) → [ 25.27079964  22.83110046  31.67569923]
# (0.0, 0.0, 0.0) → [ 21.05680084  24.02910042  31.32769966]
# (0.0, 0.0, 0.0) → [ 22.68880081  24.17009926  30.66270065]
# (0.0, 0.0, 0.0) → [ 20.95879936  26.1480999   31.67670059]
# (0.0, 0.0, 0.0) → [ 17.39480019  23.60110092  31.32869911]
# (0.0, 0.0, 0.0) → [ 18.30279922  24.96610069  30.6637001 ]
# (0.0, 0.0, 0.0) → [ 15.67679977  24.8470993   31.67770004]
# (0.0, 0.0, 0.0) → [ 15.44579983  20.47310066  31.32869911]
# (0.0, 0.0, 0.0) → [ 14.94379997  22.03409958  30.6637001 ]
# (0.0, 0.0, 0.0) → [ 13.40180016  19.90609932  31.67670059]
# (0.0, 0.0, 0.0) → [ 16.67779922  16.99909973  31.32769966]
# (0.0, 0.0, 0.0) → [ 15.14579964  17.57909966  30.6637001 ]
# (0.0, 0.0, 0.0) → [ 15.84679985  15.04710007  31.67670059]
# (0.0, 0.0, 0.0) → [ 16.02779961  14.93710041  36.21269989]
# (0.0, 0.0, 0.0) → [ 18.67480087  13.52810001  36.9817009 ]
# (0.0, 0.0, 0.0) → [ 21.17079926  13.92809963  31.67670059]
# Either use the returned `OEMol()` or save as `mol2` to continue...

# %%
save_mol2('bcd-ben/generated/bcd.oe.mol2', mol, standard=False)
save_pdb('bcd-ben/generated/bcd.oe.pdb', mol)

# %%
omm_top, omm_pos = oeommutils.oemol_to_openmmTop(mol)
ff = ForceField('forcefield/smirnoff99Frosst.ffxml', 'forcefield/tip3p.ffxml') 
system = ff.createSystem(omm_top, 
                         [mol])
structure = pmd.openmm.topsystem.load_topology(omm_top, system)

# %% [markdown]
# If I export the `mol2` file here using ParmEd, there will be no coordinates. I'm not sure why.
#
# So I'll setup a "dummy" integrator and simulation that will allow me to set the positions.

# %%
integrator = openmm.VerletIntegrator(2.0*unit.femtoseconds)
simulation = app.Simulation(omm_top, system, integrator)

# %% [markdown]
# Then I'll set the positions...

# %%
from pdbfixer import PDBFixer
fixer = PDBFixer('bcd-ben/generated/bcd.oe.pdb')
simulation.context.setPositions(fixer.positions)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-227-7f9c1ab6310a> in <module>()
#       1 from pdbfixer import PDBFixer
# ----> 2 fixer = PDBFixer('bcd-ben/generated/bcd.oe.pdb')
#       3 simulation.context.setPositions(fixer.positions)
#
# ~/data/applications/anaconda3/envs/openforcefield/lib/python3.6/site-packages/pdbfixer/pdbfixer.py in __init__(self, filename, pdbfile, pdbxfile, url, pdbid)
#     236                 self._initializeFromPDBx(file.read())
#     237             else:
# --> 238                 self._initializeFromPDB(file)
#     239             file.close()
#     240         elif pdbfile:
#
# ~/data/applications/anaconda3/envs/openforcefield/lib/python3.6/site-packages/pdbfixer/pdbfixer.py in _initializeFromPDB(self, file)
#     274
#     275         structure = PdbStructure(file)
# --> 276         pdb = app.PDBFile(structure)
#     277         self.topology = pdb.topology
#     278         self.positions = pdb.positions
#
# ~/data/applications/anaconda3/envs/openforcefield/lib/python3.6/site-packages/simtk/openmm/app/pdbfile.py in __init__(self, file, extraParticleIdentifier)
#     157             self._positions.append(coords*nanometers)
#     158         ## The atom positions read from the PDB file.  If the file contains multiple frames, these are the positions in the first frame.
# --> 159         self.positions = self._positions[0]
#     160         self.topology.setPeriodicBoxVectors(pdb.get_periodic_box_vectors())
#     161         self.topology.createStandardBonds()
#
# IndexError: list index out of range

# %% [markdown]
# Setting the positions doesn't seem to work using a PDB from OpenEye and PDBFixer.

# %%
from postprocess import *

# %%
coordinates = extract_coordinates('bcd-ben/generated/bcd.oe.mol2', None)

# %%
coordinates
# Out:
# [[19.5008, 14.9361, 31.4607],
#  [18.8128, 15.0201, 32.8307],
#  [18.7078, 16.0851, 33.0527],
#  [19.5428, 14.3631, 34.0117],
#  [19.7008, 13.3021, 33.7997],
#  [18.7438, 14.4971, 35.2987],
#  [18.6778, 15.5491, 35.5937],
#  [17.3498, 13.9361, 35.1097],
#  [17.4008, 12.8591, 34.9247],
#  [16.6428, 14.6231, 33.9447],
#  [15.6508, 14.1481, 33.8157],
#  [17.4488, 14.4391, 32.7227],
#  [16.5168, 16.0551, 34.2477],
#  [15.1728, 16.5901, 34.0127],
#  [14.4418, 15.8061, 33.7997],
#  [15.2308, 17.5711, 32.8307],
#  [15.9978, 18.3161, 33.0537],
#  [13.9258, 18.2761, 32.7227],
#  [13.5678, 19.0201, 33.9457],
#  [12.5768, 19.4991, 33.8177],
#  [13.4708, 18.0381, 35.1107],
#  [12.6608, 17.3271, 34.9257],
#  [14.7808, 17.2991, 35.2977],
#  [15.5618, 18.0051, 35.5937],
#  [14.5568, 16.3261, 36.3307],
#  [13.2158, 18.7551, 36.3287],
#  [14.6088, 20.0111, 34.2487],
#  [14.1888, 21.3961, 34.0127],
#  [13.1198, 21.4791, 33.8017],
#  [14.9918, 21.9621, 32.8317],
#  [16.0528, 21.8271, 33.0537],
#  [14.7288, 23.4221, 32.7237],
#  [15.0878, 24.1661, 33.9467],
#  [14.8458, 25.2391, 33.8177],
#  [14.2618, 23.6291, 35.1107],
#  [13.1998, 23.8181, 34.9267],
#  [14.4998, 22.1441, 35.2987],
#  [15.5388, 21.9741, 35.5937],
#  [13.5998, 21.7121, 36.3317],
#  [14.6628, 24.2761, 36.3297],
#  [16.5118, 23.9691, 34.2487],
#  [17.3328, 25.1601, 34.0127],
#  [16.7318, 26.0481, 33.8007],
#  [18.2758, 24.8851, 32.8317],
#  [18.8318, 23.9721, 33.0537],
#  [19.2538, 26.0011, 32.7227],
#  [20.0598, 26.1851, 33.9447],
#  [20.7468, 27.0441, 33.8167],
#  [19.1238, 26.4971, 35.1097],
#  [18.6108, 27.4451, 34.9247],
#  [18.1128, 25.3861, 35.2977],
#  [18.6268, 24.4671, 35.5937],
#  [17.2128, 25.8201, 36.3307],
#  [19.8808, 26.5871, 36.3287],
#  [20.7928, 24.9491, 34.2477],
#  [22.2368, 25.0511, 34.0117],
#  [22.5558, 26.0741, 33.7987],
#  [22.6088, 24.1411, 32.8307],
#  [22.2428, 23.1371, 33.0537],
#  [24.0918, 24.0731, 32.7217],
#  [24.7378, 23.5581, 33.9447],
#  [25.8378, 23.5561, 33.8147],
#  [24.3988, 24.4841, 35.1087],
#  [24.8198, 25.4761, 34.9237],
#  [22.8988, 24.5821, 35.2977],
#  [22.5008, 23.6071, 35.5927],
#  [22.6768, 25.5561, 36.3307],
#  [24.9398, 23.9491, 36.3277],
#  [24.2288, 22.2141, 34.2477],
#  [25.2088, 21.1471, 34.0117],
#  [26.2068, 21.5371, 33.7997],
#  [24.7298, 20.2891, 32.8317],
#  [23.7168, 19.9501, 33.0527],
#  [25.6008, 19.0871, 32.7227],
#  [25.5998, 18.2621, 33.9457],
#  [26.2848, 17.4001, 33.8177],
#  [26.1128, 19.1051, 35.1107],
#  [27.1508, 19.3941, 34.9257],
#  [25.2538, 20.3381, 35.2987],
#  [24.2438, 20.0401, 35.5937],
#  [25.8768, 21.1191, 36.3317],
#  [26.0318, 18.3481, 36.3287],
#  [24.2318, 17.8211, 34.2487],
#  [24.0098, 16.3911, 34.0127],
#  [24.9368, 15.8531, 33.8007],
#  [23.0398, 16.2301, 32.8307],
#  [22.1428, 16.8121, 33.0537],
#  [22.6438, 14.8011, 32.7237],
#  [21.9968, 14.2851, 33.9457],
#  [21.7498, 13.2131, 33.8177],
#  [20.8008, 15.0811, 34.2487],
#  [22.9758, 14.4101, 35.1107],
#  [23.8488, 13.7791, 34.9257],
#  [23.4048, 15.8501, 35.2987],
#  [22.5428, 16.4551, 35.5937],
#  [24.4028, 15.8501, 36.3327],
#  [22.3328, 14.0021, 36.3287],
#  [23.5348, 16.7151, 31.4607],
#  [24.9588, 16.5761, 31.3557],
#  [24.6598, 20.9781, 31.4607],
#  [25.6548, 22.0041, 31.3547],
#  [22.0258, 24.5151, 31.4597],
#  [21.8448, 25.9331, 31.3537],
#  [17.6198, 24.6631, 31.4607],
#  [16.3978, 25.4041, 31.3557],
#  [14.7568, 21.3101, 31.4617],
#  [13.4138, 20.8171, 31.3557],
#  [15.5938, 16.9811, 31.4607],
#  [15.1418, 15.6251, 31.3547],
#  [16.6288, 14.1821, 36.3287],
#  [19.3658, 13.7161, 36.3317],
#  [20.2798, 13.7381, 31.3547],
#  [20.1628, 15.7951, 31.3287],
#  [18.7538, 14.9591, 30.6637],
#  [13.9788, 16.7481, 36.9827],
#  [13.4308, 19.6951, 36.2137],
#  [13.5698, 22.4281, 36.9837],
#  [15.5308, 24.6941, 36.2137],
#  [17.7538, 26.2891, 36.9817],
#  [20.7498, 26.1691, 36.2127],
#  [23.3808, 25.4261, 36.9817],
#  [25.1548, 23.0091, 36.2127],
#  [26.2148, 20.4871, 36.9827],
#  [25.4308, 17.5941, 36.2137],
#  [24.1198, 15.1931, 36.9827],
#  [21.3688, 14.0011, 36.2137],
#  [23.2768, 17.7681, 31.3277],
#  [23.0518, 16.1451, 30.6637],
#  [25.3648, 17.3911, 31.6777],
#  [23.6758, 21.4321, 31.3287],
#  [24.8038, 20.2441, 30.6637],
#  [25.2708, 22.8311, 31.6757],
#  [21.0568, 24.0291, 31.3277],
#  [22.6888, 24.1701, 30.6627],
#  [20.9588, 26.1481, 31.6767],
#  [17.3948, 23.6011, 31.3287],
#  [18.3028, 24.9661, 30.6637],
#  [15.6768, 24.8471, 31.6777],
#  [15.4458, 20.4731, 31.3287],
#  [14.9438, 22.0341, 30.6637],
#  [13.4018, 19.9061, 31.6767],
#  [16.6778, 16.9991, 31.3277],
#  [15.1458, 17.5791, 30.6637],
#  [15.8468, 15.0471, 31.6767],
#  [16.0278, 14.9371, 36.2127],
#  [18.6748, 13.5281, 36.9817],
#  [21.1708, 13.9281, 31.6767]]

# %%
# Residue name is okay, but the atom type is missing.
structure.save('bcd-ben/generated/bcd.pmd.mol2')
structure.save('bcd-ben/generated/bcd.pmd.prmtop')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-215-f33569f047a0> in <module>()
#       1 # Residue name is okay, but the atom type is missing.
# ----> 2 structure.save('bcd-ben/generated/bcd.pmd.mol2')
#       3 structure.save('bcd-ben/generated/bcd.pmd.prmtop')
#
# ~/data/applications/anaconda3/envs/openforcefield/lib/python3.6/site-packages/parmed/structure.py in save(self, fname, format, overwrite, **kwargs)
#    1476         if not hasattr(fname, 'write'):
#    1477             if os.path.exists(fname) and not overwrite:
# -> 1478                 raise IOError('%s exists; not overwriting' % fname)
#    1479         else:
#    1480             if format is None:
#
# OSError: bcd-ben/generated/bcd.pmd.mol2 exists; not overwriting

# %%
from pdbfixer import PDBFixer
pdb = PDBFixer('bcd-ben/bcd-ben-conect.pdb')

# %%
ff = ForceField('forcefield/smirnoff99Frosst.ffxml', 'forcefield/tip3p.ffxml') 
system = ff.createSystem(pdb.topology, 
                         molecules)
integrator = openmm.VerletIntegrator(1.0 * unit.femtoseconds)
context = openmm.Context(system, integrator)
context.setPositions(pdb.positions)

# %% [markdown]
# # Testing `preprocess.py`

# %%
from preprocess import *

# %%
create_pdb_with_conect('bcd-ben.pdb', 'solvated.prmtop', 'bcd-ben-test.pdb', path='bcd-ben/')
# Out:
# PDB file written by cpptraj.

# %%
prune_conect('bcd-ben-test.pdb', 'bcd-ben-test-conect.pdb', path='bcd-ben/')
# Out:
# First water residue = 175
# Found first water CONECT entry at line = 9192

# %% [markdown]
# # Testing `postprocess.py`
